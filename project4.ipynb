# %%
import pandas as pd

# %%
csv_path = "Resources/cancer patient data sets.csv"
lung_cancer_df = pd.read_csv(csv_path)
lung_cancer_df.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
lung_cancer_df["Level_cat"] = pd.Categorical(lung_cancer_df.Level).codes

# %%
pd.Categorical(lung_cancer_df.Level).codes

# %%
lung_cancer_df.corr()['Level_cat']
# Out:
# Age                         0.042631
# Gender                      0.086222
# Air Pollution              -0.577269
# Alcohol use                -0.434071
# Dust Allergy               -0.264926
# OccuPational Hazards       -0.363748
# Genetic Risk               -0.423382
# chronic Lung Disease       -0.432405
# Balanced Diet              -0.618781
# Obesity                    -0.561961
# Smoking                    -0.611087
# Passive Smoker             -0.638409
# Chest Pain                 -0.494704
# Coughing of Blood          -0.631118
# Fatigue                    -0.403276
# Weight Loss                -0.020537
# Shortness of Breath        -0.140178
# Wheezing                    0.167773
# Swallowing Difficulty      -0.012880
# Clubbing of Finger Nails    0.116746
# Frequent Cold              -0.171678
# Dry Cough                  -0.228720
# Snoring                     0.014280
# Level_cat                   1.000000
# Name: Level_cat, dtype: float64
